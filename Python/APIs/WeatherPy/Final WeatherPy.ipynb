# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
# originally used openweathermapy but later decided to redo it the old-fashioned way
import openweathermapy.core as owm

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 633

# %%
# base url
url='http://api.openweathermap.org/data/2.5/weather?'
# initializing empty dataframe to later fill
cityweatherdf=pd.DataFrame(columns=('City', 'Cloudiness','Country', 'Date', 'Humidity', 'Lat', 'Lng', 'Max Temp', 'Wind Speed'))
externalcounter=0

for city in cities:
    # completingurl
    query_url= url+'&appid='+api_key+'&units=metric'+'&q='+city
    # The following code skips to the next loop if a city's weather data is not available on OWM 
    try:
        data=requests.get(query_url).json()
    except:
        print(city, "is not available on OWM")
        continue
    # Similarly, sometimes the data was not complete, or, oddly, it would give random errors for certain cities
    # Thus, the following code skips to the next loop, if such a city is queried.
    try:
        # Adding city data row by row to the initially empty dataframe
        cityweatherdf.loc[externalcounter]=[city]+[data['clouds']['all'],data['sys']['country'],data['dt'], data['main']['humidity'], data['coord']['lat'], data['coord']['lon'], data['main']['temp_max'], data['wind']['speed']]
    except:
        print(city, "is either not available on OWM at all or parts of the data are not available")
        continue
    # printing city count, and city name
    print(externalcounter,city)
    externalcounter=externalcounter+1
# Out:
# 0 mataura
# 1 bredasdorp
# 2 inhambane
# 3 rikitea
# 4 farafangana
# 5 thessalon
# 6 cabo san lucas
# 7 sao filipe
# 8 chapais
# 9 hermosillo
# 10 new norfolk
# 11 klaksvik
# 12 albany
# 13 chenghai
# 14 robertson
# 15 hilo
# 16 grindavik
# 17 vaini
# 18 cayenne
# 19 medianeira
# 20 qaanaaq
# 21 punta arenas
# imabari is either not available on OWM at all or parts of the data are not available
# 22 avera
# 23 isangel
# 24 vila
# 25 hobyo
# 26 campbell river
# 27 east london
# 28 fort smith
# 29 great yarmouth
# 30 francisco morato
# illoqqortoormiut is either not available on OWM at all or parts of the data are not available
# 31 bluff
# 32 katsuura
# 33 port lincoln
# 34 shupiyan
# 35 palana
# 36 narsaq
# belushya guba is either not available on OWM at all or parts of the data are not available
# 37 port alfred
# 38 bailen
# 39 verkhnyaya inta
# 40 brae
# saleaula is either not available on OWM at all or parts of the data are not available
# 41 avarua
# 42 bontang
# 43 tuktoyaktuk
# 44 fairbanks
# 45 bambous virieux
# 46 touros
# 47 tura
# 48 san cristobal
# tabiauea is either not available on OWM at all or parts of the data are not available
# 49 dikson
# 50 hobart
# 51 ushuaia
# 52 husavik
# 53 naze
# 54 vila franca do campo
# 55 komsomolskiy
# 56 eyl
# 57 banda aceh
# 58 saint anthony
# 59 bereda
# 60 bure
# asau is either not available on OWM at all or parts of the data are not available
# 61 kavieng
# 62 tubuala
# barentsburg is either not available on OWM at all or parts of the data are not available
# 63 chuy
# 64 puerto ayora
# 65 dingzhou
# 66 cape town
# 67 kruisfontein
# 68 tigzirt
# 69 masallatah
# 70 kahului
# 71 bambanglipuro
# 72 kapaa
# 73 aksarka
# 74 poopo
# palabuhanratu is either not available on OWM at all or parts of the data are not available
# 75 laguna
# 76 saint-philippe
# 77 los llanos de aridane
# 78 hermanus
# 79 yellowknife
# el wasta is either not available on OWM at all or parts of the data are not available
# 80 manjacaze
# 81 bela
# urumqi is either not available on OWM at all or parts of the data are not available
# 82 romanovo
# 83 sarangani
# 84 severo-kurilsk
# 85 barrow
# 86 kodiak
# 87 calama
# 88 ilulissat
# 89 egvekinot
# 90 atuona
# 91 tasiilaq
# 92 busselton
# 93 zhangye
# 94 luganville
# 95 nadym
# 96 aklavik
# 97 ribeira grande
# 98 paramonga
# bengkulu is either not available on OWM at all or parts of the data are not available
# 99 marawi
# 100 vila velha
# 101 launceston
# 102 filingue
# 103 vestmannaeyjar
# 104 pacific grove
# amderma is either not available on OWM at all or parts of the data are not available
# maridi is either not available on OWM at all or parts of the data are not available
# 105 westport
# 106 maple grove
# 107 georgetown
# addi ugri is either not available on OWM at all or parts of the data are not available
# 108 butaritari
# taolanaro is either not available on OWM at all or parts of the data are not available
# 109 severobaykalsk
# 110 carnarvon
# 111 dingle
# 112 tiksi
# 113 inuvik
# 114 lagoa
# 115 mitsamiouli
# 116 broken hill
# 117 freeport
# 118 jales
# 119 nome
# 120 coquimbo
# 121 hasaki
# 122 erdenet
# 123 arraial do cabo
# 124 chilca
# 125 high level
# 126 tieli
# 127 loreto
# 128 chegdomyn
# 129 yamada
# 130 pevek
# 131 lasa
# 132 pitkyaranta
# 133 matara
# 134 beringovskiy
# 135 walvis bay
# 136 songjianghe
# 137 shenjiamen
# 138 port elizabeth
# 139 srednekolymsk
# 140 tambovka
# 141 saint george
# 142 amberley
# 143 ponta delgada
# 144 astorga
# 145 karaton
# olafsvik is either not available on OWM at all or parts of the data are not available
# 146 ponta do sol
# 147 yulara
# sedelnikovo is either not available on OWM at all or parts of the data are not available
# 148 san patricio
# 149 uglegorsk
# xiongshi is either not available on OWM at all or parts of the data are not available
# 150 sitka
# 151 mount pleasant
# 152 isiro
# 153 san antonio
# 154 manzil salim
# 155 majene
# 156 nouadhibou
# 157 mehamn
# 158 khatanga
# 159 heishan
# 160 anshun
# 161 nikolayevsk-na-amure
# 162 two rivers
# 163 la asuncion
# 164 adrar
# 165 clyde river
# 166 porto novo
# 167 sisimiut
# 168 rognan
# 169 kapit
# 170 kayes
# 171 sola
# 172 mar del plata
# 173 pahalgam
# 174 lingao
# 175 labuhan
# 176 gornoye loo
# 177 novokruchininskiy
# 178 port hardy
# 179 bethel
# 180 boras
# 181 mama
# 182 forbes
# 183 jumla
# 184 ulaanbaatar
# 185 knokke-heist
# 186 cherskiy
# 187 kijang
# 188 nueva guinea
# ndende is either not available on OWM at all or parts of the data are not available
# 189 ancud
# 190 meulaboh
# 191 mayo
# 192 gravdal
# 193 seoul
# 194 valverde del camino
# 195 fortuna
# 196 lompoc
# 197 esperance
# 198 balakovo
# 199 pemberton
# 200 victoria
# 201 nikolskoye
# 202 moose factory
# 203 leon
# 204 roald
# 205 aksu
# 206 longyearbyen
# 207 lebu
# 208 boa vista
# 209 saldanha
# 210 sovetskiy
# 211 limbang
# 212 talnakh
# 213 jamestown
# 214 chas
# 215 provideniya
# 216 oktyabrskoye
# 217 ardabil
# 218 emerald
# 219 praya
# 220 trincomalee
# 221 saskylakh
# 222 maniitsoq
# 223 conceicao do araguaia
# 224 tazmalt
# tsihombe is either not available on OWM at all or parts of the data are not available
# 225 kathu
# 226 hithadhoo
# 227 santa maria
# 228 geraldton
# 229 zaranj
# tumannyy is either not available on OWM at all or parts of the data are not available
# 230 zhuhai
# 231 krasnoarmeysk
# 232 junction city
# 233 xining
# 234 san ramon
# 235 torbay
# 236 cairns
# 237 kibre mengist
# 238 chiusi
# 239 richards bay
# 240 mangrol
# 241 yagodnoye
# 242 mbini
# 243 bandarbeyla
# 244 mokobeng
# 245 plettenberg bay
# 246 varhaug
# 247 chokurdakh
# 248 shinjo
# vaitupu is either not available on OWM at all or parts of the data are not available
# 249 mahebourg
# 250 jvari
# 251 port hawkesbury
# 252 cap malheureux
# babanusah is either not available on OWM at all or parts of the data are not available
# 253 mugur-aksy
# 254 paita
# 255 atherton
# 256 baculin
# kegayli is either not available on OWM at all or parts of the data are not available
# 257 cidreira
# 258 castro
# 259 xalpatlahuac
# 260 nanortalik
# 261 tezu
# crab hill is either not available on OWM at all or parts of the data are not available
# 262 pierre
# 263 acajutla
# 264 sawakin
# 265 belmonte
# 266 zhuanghe
# 267 mitzic
# 268 jardim
# 269 huarmey
# 270 jieshi
# bokspits is either not available on OWM at all or parts of the data are not available
# 271 vrangel
# 272 aripuana
# 273 angoche
# 274 ostrovnoy
# 275 mankono
# 276 cockburn town
# 277 coolum beach
# 278 mandalgovi
# 279 gore
# 280 southbridge
# 281 tuatapere
# 282 svetlogorsk
# 283 berlevag
# nizhneyansk is either not available on OWM at all or parts of the data are not available
# 284 kattivakkam
# 285 galveston
# 286 daru
# tome-acu is either not available on OWM at all or parts of the data are not available
# 287 yar-sale
# 288 manggar
# 289 gizo
# 290 shahrud
# 291 colesberg
# 292 hami
# 293 indianola
# 294 biu
# 295 filadelfia
# 296 shimoda
# 297 baruun-urt
# 298 tymovskoye
# 299 stepnyak
# 300 gidole
# 301 xai-xai
# 302 hofn
# 303 yicheng
# 304 mrakovo
# harunabad is either not available on OWM at all or parts of the data are not available
# 305 norman wells
# 306 maragogi
# 307 preeceville
# bolungarvik is either not available on OWM at all or parts of the data are not available
# 308 nabire
# 309 skala fourkas
# 310 upernavik
# 311 banjar
# 312 verkhniy tagil
# 313 chone
# 314 vyazemskiy
# 315 katherine
# 316 zapolyarnyy
# 317 terrace
# 318 watertown
# 319 ajaccio
# 320 ladario
# 321 bushehr
# 322 arti
# 323 eirunepe
# 324 wamba
# 325 alofi
# 326 west wendover
# 327 atar
# 328 guerrero negro
# 329 tari
# 330 havre-saint-pierre
# 331 antiguo morelos
# 332 zyryanskoye
# 333 brewster
# 334 vaasa
# 335 port hedland
# 336 poian
# 337 mitu
# 338 namwala
# erhlin is either not available on OWM at all or parts of the data are not available
# 339 okhotsk
# 340 stanger
# 341 la paz
# 342 kuandian
# 343 codrington
# 344 humboldt
# 345 deputatskiy
# 346 celestun
# 347 vardo
# 348 chimbote
# 349 bathsheba
# 350 kavaratti
# 351 havelock
# 352 merauke
# 353 metkovic
# 354 sungaipenuh
# 355 ukiah
# 356 porec
# 357 singaparna
# 358 port macquarie
# litoral del san juan is either not available on OWM at all or parts of the data are not available
# 359 sorland
# 360 xinqing
# 361 gorontalo
# 362 muros
# 363 moyale
# 364 thompson
# dibaya is either not available on OWM at all or parts of the data are not available
# 365 xinyu
# 366 souillac
# 367 margate
# 368 amga
# ozgon is either not available on OWM at all or parts of the data are not available
# 369 nhulunbuy
# 370 verkhoyansk
# 371 whitehorse
# 372 olinda
# 373 golspie
# 374 kaitangata
# 375 jaguarao
# karamay is either not available on OWM at all or parts of the data are not available
# 376 umm lajj
# 377 karratha
# 378 cedar city
# 379 fasa
# 380 antalaha
# 381 yeniseysk
# 382 leningradskiy
# 383 paamiut
# 384 college
# 385 lakinsk
# 386 kitgum
# 387 verkhnevilyuysk
# louisbourg is either not available on OWM at all or parts of the data are not available
# 388 sorso
# 389 hamilton
# 390 carmelo
# 391 tevaitoa
# 392 mount isa
# 393 yatou
# 394 livingston
# 395 auki
# 396 sweetwater
# 397 lerwick
# manzil jamil is either not available on OWM at all or parts of the data are not available
# 398 noumea
# 399 sokolo
# 400 deniliquin
# attawapiskat is either not available on OWM at all or parts of the data are not available
# 401 port blair
# 402 morgan city
# 403 cayhagan
# 404 taoudenni
# 405 caravelas
# 406 obertyn
# 407 byron bay
# 408 iqaluit
# 409 dwarka
# 410 koumac
# 411 lavrentiya
# 412 ambilobe
# 413 azua
# 414 samarai
# 415 madimba
# 416 kailua
# 417 reconquista
# 418 derzhavinsk
# 419 dunedin
# 420 hanumangarh
# 421 ocampo
# 422 comodoro rivadavia
# 423 zabaykalsk
# 424 ati
# 425 luderitz
# 426 kirovskaya
# 427 turukhansk
# 428 vao
# 429 banfora
# 430 lorengau
# 431 vikulovo
# 432 starodub
# 433 saint-dizier
# 434 valley city
# 435 tual
# 436 tonantins
# kerki is either not available on OWM at all or parts of the data are not available
# 437 xichang
# 438 kanakapura
# 439 bafq
# 440 letlhakeng
# 441 micco
# skalistyy is either not available on OWM at all or parts of the data are not available
# 442 tessalit
# 443 ijevan
# 444 teya
# 445 oistins
# 446 linqiong
# 447 manta
# 448 vanimo
# 449 pitimbu
# 450 ahipara
# 451 aswan
# 452 una
# 453 coihaique
# 454 oktyabrskiy
# 455 north bend
# 456 ha giang
# sakakah is either not available on OWM at all or parts of the data are not available
# sitio novo do tocantins is either not available on OWM at all or parts of the data are not available
# 457 taos
# 458 praia
# 459 vostok
# 460 kaiserslautern
# 461 srandakan
# 462 jagtial
# 463 pudozh
# 464 bunia
# 465 albert
# 466 singaraja
# 467 miri
# chagda is either not available on OWM at all or parts of the data are not available
# 468 carlsbad
# 469 ossora
# 470 urengoy
# 471 chancay
# ruatoria is either not available on OWM at all or parts of the data are not available
# 472 vilya
# 473 rawson
# 474 kununurra
# 475 rock sound
# 476 tabuk
# ust-kamchatsk is either not available on OWM at all or parts of the data are not available
# 477 airai
# 478 belyy yar
# 479 resistencia
# 480 kamskiye polyany
# 481 imbituba
# 482 north augusta
# 483 wangqing
# 484 ternate
# 485 seara
# 486 ayan
# warqla is either not available on OWM at all or parts of the data are not available
# 487 shawville
# 488 aykhal
# 489 guarapari
# dvur kralove is either not available on OWM at all or parts of the data are not available
# 490 octeville
# 491 henties bay
# 492 pemba
# 493 turbat
# 494 labuan
# 495 santa cruz
# 496 mulege
# 497 provost
# mys shmidta is either not available on OWM at all or parts of the data are not available
# 498 dahod
# 499 salalah
# 500 suoyarvi
# 501 burkburnett
# ye is either not available on OWM at all or parts of the data are not available
# 502 nantucket
# 503 am timan
# 504 uvinza
# 505 kinkala
# 506 honiara
# 507 guangshui
# 508 mareeba
# 509 gilgit
# fevralsk is either not available on OWM at all or parts of the data are not available
# 510 lebanon
# 511 taltal
# 512 zhigansk
# 513 lake shore
# arrecife is either not available on OWM at all or parts of the data are not available
# 514 macia
# 515 harrai
# samusu is either not available on OWM at all or parts of the data are not available
# 516 shu
# 517 kandava
# 518 qeshm
# 519 luanda
# 520 oranjemund
# matameye is either not available on OWM at all or parts of the data are not available
# 521 hidalgo
# 522 villa bruzual
# 523 boshnyakovo
# 524 makakilo city
# 525 quatre cocos
# marcona is either not available on OWM at all or parts of the data are not available
# 526 lata
# 527 luebo
# 528 deda
# 529 chiredzi
# 530 tignere
# 531 neklyudovo
# 532 sioux lookout
# 533 uyovu
# 534 elizabeth city
# 535 pavlogradka
# 536 port moresby
# 537 greeneville
# 538 gazanjyk
# 539 general roca
# 540 douglas
# 541 kathmandu
# 542 amapa
# 543 kupang
# 544 manacapuru
# 545 tahoua
# 546 pozo colorado
# 547 deer lake
# 548 portland
# daxian is either not available on OWM at all or parts of the data are not available
# 549 leh
# 550 bafata
# 551 ahuimanu
# 552 murmashi
# jahrom is either not available on OWM at all or parts of the data are not available
# 553 champerico
# 554 monte alegre
# da nang is either not available on OWM at all or parts of the data are not available
# 555 clarence town
# 556 sitges
# 557 buala
# 558 denpasar
# 559 kenai
# 560 chaozhou
# sentyabrskiy is either not available on OWM at all or parts of the data are not available
# 561 poum
# 562 ulverstone
# 563 namibe
# 564 atbasar
# kamenskoye is either not available on OWM at all or parts of the data are not available
# 565 pangoa
# 566 terrasini
# 567 abnub
# 568 hambantota
# lhuntshi is either not available on OWM at all or parts of the data are not available
# 569 te anau
# 570 chickasha
# 571 miramar
# 572 ust-nera

# %%
# visualizing the now full dataframe
cityweatherdf
# Out:
#                City Cloudiness Country        Date Humidity    Lat     Lng  \
# 0           mataura        100      NZ  1576471386       71 -46.19  168.86
# 1        bredasdorp         30      ZA  1576471386       87 -34.53   20.04
# 2         inhambane         75      MZ  1576471386       88 -23.87   35.38
# 3           rikitea         37      PF  1576471387       75 -23.12 -134.97
# 4       farafangana          0      MG  1576471387       79 -22.82   47.83
# 5         thessalon         75      CA  1576471387       85  46.26  -83.55
# 6    cabo san lucas         40      MX  1576471346       64  22.89 -109.91
# 7        sao filipe         93      CV  1576471387       81  14.90  -24.50
# 8           chapais          1      CA  1576471387       76  49.78  -74.86
# 9        hermosillo          5      MX  1576471283       87  29.09 -110.96
# 10      new norfolk         40      AU  1576471387       45 -42.78  147.06
# 11         klaksvik         83      FO  1576471388       81  62.23   -6.59
# 12           albany         20      US  1576471203       50  42.65  -73.75
# 13         chenghai         75      CN  1576471388       64  23.46  116.77
# 14        robertson         75      AU  1576471388       52 -34.59  150.59
# 15             hilo          1      US  1576471388       73  19.71 -155.08
# 16        grindavik         50      IS  1576471388       71  63.84  -22.43
# 17            vaini         88      IN  1576471389       69  15.34   74.49
# 18          cayenne         75      GF  1576471389      100   4.94  -52.33
# 19       medianeira        100      BR  1576471389       94 -25.30  -54.09
# 20          qaanaaq         61      GL  1576471389       56  77.48  -69.36
# 21     punta arenas         20      CL  1576471389       81 -53.16  -70.91
# 22            avera          1      US  1576471538      100  33.19  -82.53
# 23          isangel         75      VU  1576471538       74 -19.55  169.27
# 24             vila         75      IT  1576471538      100  45.18    8.40
# 25            hobyo         46      SO  1576471539       64   5.35   48.53
# 26   campbell river         90      CA  1576471539       74  50.02 -125.24
# 27      east london         12      ZA  1576471539       63 -33.02   27.91
# 28       fort smith         90      US  1576471539      100  35.39  -94.42
# 29   great yarmouth         86      GB  1576471539       97  52.61    1.73
# ..              ...        ...     ...         ...      ...    ...     ...
# 543          kupang         40      ID  1576471349       74 -10.16  123.60
# 544      manacapuru        100      BR  1576471623      100  -3.30  -60.62
# 545          tahoua          0      NE  1576471373       17  14.89    5.26
# 546   pozo colorado        100      PY  1576471623       96 -23.49  -58.80
# 547       deer lake         90      CA  1576471624       74  49.18  -57.43
# 548        portland          1      US  1576471535       36  43.66  -70.25
# 549             leh         22      IN  1576471624       45  34.16   77.58
# 550          bafata          0      GW  1576471624       69  12.17  -14.67
# 551        ahuimanu         75      US  1576471624       78  21.44 -157.84
# 552        murmashi         75      RU  1576471624       86  68.82   32.82
# 553      champerico          5      MX  1576471625       78  16.38  -93.60
# 554    monte alegre        100      BR  1576471625       92  -2.00  -54.07
# 555   clarence town         75      AU  1576471625       56 -32.59  151.78
# 556          sitges         20      ES  1576471626       87  41.24    1.82
# 557           buala         55      SB  1576471626       75  -8.15  159.59
# 558        denpasar         40      ID  1576471597       74  -8.65  115.22
# 559           kenai         20      US  1576471626       59  60.55 -151.26
# 560        chaozhou         75      CN  1576471626       64  23.66  116.62
# 561            poum         90      MK  1576471626       86  41.28   20.71
# 562      ulverstone          0      AU  1576471626       60 -41.16  146.17
# 563          namibe         50      AO  1576471627       82 -15.19   12.15
# 564         atbasar         84      KZ  1576471627       90  51.81   68.36
# 565          pangoa         97      PE  1576471627       99 -12.12  -73.00
# 566       terrasini         26      IT  1576471627       82  38.15   13.08
# 567           abnub          0      EG  1576471627        3  27.27   31.15
# 568      hambantota         75      LK  1576471627       88   6.12   81.12
# 569         te anau        100      NZ  1576471628       73 -45.41  167.72
# 570       chickasha         90      US  1576471628       81  35.05  -97.94
# 571         miramar         32      CR  1576471628       60  10.09  -84.73
# 572        ust-nera        100      RU  1576471628      100  64.57  143.24
#
#      Max Temp  Wind Speed
# 0       13.74        4.71
# 1        9.00        2.10
# 2       23.00        7.70
# 3       22.31        8.87
# 4       26.92        3.24
# 5       -8.00        1.11
# 6       22.22        5.10
# 7       20.51       10.23
# 8      -22.00        6.70
# 9       17.22        1.50
# 10      20.56        7.70
# 11       3.00        3.60
# 12      -1.67        5.70
# 13      23.00        2.00
# 14      22.78        6.70
# 15      24.00        2.24
# 16       0.00        5.10
# 17      23.00        3.10
# 18      25.00        1.00
# 19      21.00        3.10
# 20     -20.22        2.74
# 21       7.00        5.70
# 22      11.11        2.73
# 23      29.00        3.10
# 24       7.22        1.00
# 25      26.84        7.43
# 26       3.00        1.50
# 27      16.00        5.10
# 28       7.00        2.10
# 29       7.22        4.02
# ..        ...         ...
# 543     31.00        4.10
# 544     21.00        1.08
# 545     18.00        4.10
# 546     21.17        2.72
# 547      2.00        5.10
# 548     -1.00       10.30
# 549    -16.77        1.42
# 550     18.36        1.15
# 551     26.00        4.10
# 552     -1.00        1.00
# 553     22.00        2.10
# 554     24.53        1.86
# 555     23.33        8.70
# 556     11.67        4.10
# 557     28.36        0.72
# 558     31.00        3.10
# 559      3.33        8.70
# 560     23.00        2.00
# 561      3.00        2.10
# 562     21.11        1.79
# 563     24.35        0.31
# 564    -14.42        2.42
# 565     20.37        0.94
# 566     15.56        2.10
# 567      9.00        3.10
# 568     28.00        4.10
# 569     12.48        4.87
# 570      1.11        5.70
# 571     22.78        5.10
# 572    -38.73        0.86
#
# [573 rows x 9 columns]

# %%
# exporting dataframe to a CSV format
export_csv = cityweatherdf.to_csv(r'C:\Users\ekamj\Documents\Bootcamp homework\Homework 6\WeatherPy\cityweather_export.csv', index = True, header=True)

# %%
# Plotting a scatter plot, with light blue markers surrounded by black edges
fig, ax = plt.subplots()
ax.scatter(list(cityweatherdf['Lat']),list(cityweatherdf['Max Temp']),c='LightBlue',edgecolors="Black")
ax.set_title('City Latitude vs Max Temperature (12/15/2019)')        
ax.set_xlabel('Latitude')
ax.set_ylabel('Maxium Temperature (C)')
ax.axes.grid()
# saving figure
fig.savefig('latitude_temperature.png')
plt.show()

# %%
# Same as before, except this time the data plotted is city latitude vs. humidity
fig, ax = plt.subplots()
ax.scatter(list(cityweatherdf['Lat']),list(cityweatherdf['Humidity']),c='LightBlue',edgecolors="Black")
ax.set_title('City Latitude vs Humidity (12/15/2019)')        
ax.set_xlabel('Latitude')
ax.set_ylabel('Humidity (%)')
ax.axes.grid()
fig.savefig('latitude_humidity.png')
plt.show()

# %%
# Same as before... except this time the data plotted is city latitude vs. cloudiness
fig, ax = plt.subplots()
ax.scatter(list(cityweatherdf['Lat']),list(cityweatherdf['Cloudiness']),c='LightBlue',edgecolors="Black")
ax.set_title('City Latitude vs. Cloudiness (12/15/2019)')        
ax.set_xlabel('Latitude')
ax.set_ylabel('Cloudiness (%)')
ax.axes.grid()
fig.savefig('latitude_cloudiness.png')
plt.show()

# %%
#... data plotted is city latitude vs Wind Speed
fig, ax = plt.subplots()
ax.scatter(list(cityweatherdf['Lat']),list(cityweatherdf['Wind Speed']),c='LightBlue',edgecolors="Black")
ax.set_title('City Latitude vs. Wind Speed (12/15/2019)')        
ax.set_xlabel('Latitude')
ax.set_ylabel('Wind Speed (mph)')
ax.axes.grid()
fig.savefig('latitude_wind_speed.png')
plt.show()
